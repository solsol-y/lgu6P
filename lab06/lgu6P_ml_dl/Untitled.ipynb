# %%
import torch

# torch 버전 확인
print("Pytorch 버전:", torch.__version__)

# CUDA 사용 가능 여부 확인
print("CUDA 사용 가능 여부:", torch.cuda.is_available())

# 사용 가능한 GPU 개수 확인
print("사용 가능한 GPU 개수:", torch.cuda.device_count())

# 현재 사용 중인 디바이스 ID
print("현재 디바이스 ID:", torch.cuda.current_device())

# 현재 디바이스 이름
print("현재 디바이스 이름:", torch.cuda.get_device_name(torch.cuda.current_device()))

# 텐서를 GPU에 할당해보기
x = torch.tensor([1.0, 2.0, 3.0]).to('cuda')
print("GPU에 할당된 텐서:", x)
# Out:
# Pytorch 버전: 2.7.0+cpu
# CUDA 사용 가능 여부: False
# 사용 가능한 GPU 개수: 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 13
#      10 print("사용 가능한 GPU 개수:", torch.cuda.device_count())
#      12 # 현재 사용 중인 디바이스 ID
# ---> 13 print("현재 디바이스 ID:", torch.cuda.current_device())
#      15 # 현재 디바이스 이름
#      16 print("현재 디바이스 이름:", torch.cuda.get_device_name(torch.cuda.current_device()))
#
# File ~\Desktop\lgu6P_ml_dl\.venv\Lib\site-packages\torch\cuda\__init__.py:1026, in current_device()
#    1024 def current_device() -> int:
#    1025     r"""Return the index of a currently selected device."""
# -> 1026     _lazy_init()
#    1027     return torch._C._cuda_getDevice()
#
# File ~\Desktop\lgu6P_ml_dl\.venv\Lib\site-packages\torch\cuda\__init__.py:363, in _lazy_init()
#     358     raise RuntimeError(
#     359         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     360         "multiprocessing, you must use the 'spawn' start method"
#     361     )
#     362 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 363     raise AssertionError("Torch not compiled with CUDA enabled")
#     364 if _cudart is None:
#     365     raise AssertionError(
#     366         "libcudart functions unavailable. It looks like you have a broken build?"
#     367     )
#
# AssertionError: Torch not compiled with CUDA enabled
